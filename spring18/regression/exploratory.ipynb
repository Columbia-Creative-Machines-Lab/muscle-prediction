# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Basic data analysis
# Exploratory data analysis: data cleaning if necessary, identifying min/max of each cycle, labeling cycles

# %% [markdown]
# ## Load dataset
# Uncomment line 2 and modify `n` for speed.

# %%
df = pd.read_csv('data/raw_cycles.csv')
#df = df.head(n=20000) # Uncomment this line to sample n rows for speed.
df.drop(0, inplace=True) # Drop units row
df = df.apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ## Preview first `n` cycles
# Plot data.

# %%
fig, ax = plt.subplots(figsize=(10,5));
ax.plot(df['Time'], df['Load']);
ax.grid(True);
ax.set_xticks(np.arange(0, df['Time'].max(), df.shape[0]/100));

# %%
fig.savefig('images/cycles_1.png');

# %% [markdown]
# ## Identify extrema
# Find local minima and maxima.

# %%
from scipy.signal import argrelextrema

# %%
minima = argrelextrema(df['Load'].values, comparator=np.less, order=100)[0]
maxima = argrelextrema(df['Load'].values, comparator=np.greater, order=100)[0]

# %% [markdown]
# ## Label cycles in data
# Cycles begin and end at each minimum.

# %%
col = np.zeros(shape=(len(df),), dtype=int)
for i in range(1, len(minima)):
    col[minima[i-1]:minima[i]] = i
df = df.assign(Cycle=pd.Series(col, index=df.index))

# %% [markdown]
# We show unique cycles in the data:

# %%
from matplotlib import cm

# %%
ax.scatter(df['Time'], df['Load'], s=5, c=df['Cycle'], cmap=cm.jet)
fig

# %%
fig.savefig('images/cycles_2.png');

# %% [markdown]
# ## Update data and file with labels

# %%
df.to_csv('data/cycles.csv', index=False)

# %%
df[df['Cycle'] == 1];

# %% [markdown]
# # Statistical analysis
# area, moment of area, curve belly, slope of upward response, etc.

# %%
#for cycle in range(df['Cycle'].max()):
#    np.trapz(df.values)

areas = []
for i in range(df['Cycle'].max()):
    cycle = df[df['Cycle'] == i].drop('Cycle', axis=1).values
    print(np.trapz(cycle))
#f = lambda cycle:  
#areas = np.fromiter((f(cycle) for cycle in), dtype=float)
#np.trapz(df.values, axis=0)
# Out:
# [3.36450000e-02 3.65400000e-02 7.72650000e-02 1.03105000e-01
#  1.51760000e-01 2.10315000e-01 2.49160000e-01 2.94085000e-01
#  3.49165000e-01 3.96720000e-01 4.39460000e-01 4.81885000e-01
#  5.38420000e-01 5.74525000e-01 6.11475000e-01 6.72505000e-01
#  7.27480000e-01 7.66030000e-01 8.38113134e+03 8.38119296e+03
#  8.38123443e+03 8.38130483e+03 8.38134405e+03 8.38138450e+03
#  8.38144741e+03 8.38149057e+03 8.38153620e+03 8.38158812e+03
#  8.38165767e+03 8.38170860e+03 8.38173997e+03 8.38179912e+03
#  8.38185105e+03 8.38189608e+03 8.38194518e+03 8.38200994e+03
#  8.38206297e+03 8.38209784e+03 8.38215749e+03 8.38220943e+03
#  8.38225507e+03 8.38230551e+03 8.38235606e+03 8.38242594e+03
#  8.38246918e+03 8.38251943e+03 8.38258000e+03 8.38261082e+03
#  8.38266675e+03 8.38271580e+03 8.38278232e+03 8.38283650e+03
#  8.38288537e+03 8.38293164e+03 8.38299003e+03 8.38302912e+03
#  8.38308474e+03 8.38314954e+03 8.38320422e+03 8.38324503e+03
#  8.38329937e+03 8.38336600e+03 8.38339518e+03 8.38344289e+03
#  8.38351737e+03 8.38357136e+03 8.38361978e+03 8.38366361e+03
#  8.38371503e+03 8.38376463e+03 8.38381148e+03 8.38387869e+03
#  8.38393011e+03 8.38398830e+03 8.38402030e+03 8.38408789e+03
#  8.38414406e+03 8.38418598e+03 8.38424472e+03 8.38430305e+03
#  8.38435650e+03 8.38439801e+03 8.38445934e+03 8.38452201e+03
#  8.38456262e+03 8.38460434e+03 8.38467772e+03 8.38473456e+03
#  8.38478463e+03 8.38482507e+03 8.38489422e+03 8.38493224e+03
#  8.38499032e+03 8.38505110e+03 8.38511361e+03 8.38515957e+03
#  8.38521044e+03 8.38527620e+03 8.38531699e+03 8.38537462e+03
#  8.38542953e+03 8.38549779e+03]
# [  0.799235   0.870565   0.917295 ... 131.097305 131.08505  131.136985]
# [131.100185 131.18032  131.32121  ... 286.81132  286.872725 286.933115]
# [286.95433  287.018165 287.070465 ... 453.19613  453.228625 453.297965]
# [453.32197  453.379535 453.4342   ... 615.81375  615.866315 615.93017 ]
# [615.94925  616.021075 616.068445 ... 777.73116  777.76842  777.83892 ]
# [777.862685 777.936365 777.976475 ... 931.917805 932.00903  932.27985 ]
# [ 931.6908    932.05816   931.885865 ... 1084.447215 1084.46994
#  1084.479425]
# [1084.501375 1084.589605 1084.67234  ... 1239.039635 1238.992875
#  1238.89137 ]
# [1238.89199  1239.02365  1239.19082  ... 1385.282925 1385.33458
#  1385.387445]
# [1385.421815 1385.49799  1385.541105 ... 1533.264545 1533.302255
#  1533.37538 ]
# [1533.38971  1533.47057  1533.525935 ... 1680.3553   1680.41262
#  1680.466985]
# [1680.49377  1680.557275 1680.612015 ... 1828.93736  1828.99175
#  1829.041835]
# [1829.07799  1829.132645 1829.19229  ... 1977.30969  1977.3769
#  1977.379955]
# [1977.421225 1977.50101  1977.544055 ... 2123.288035 2123.334615
#  2123.36421 ]
# [2123.398115 2123.456495 2123.51462  ... 2269.99888  2270.046905
#  2270.09479 ]
# [2270.13582  2270.201635 2270.253645 ... 2417.21533  2417.25981
#  2417.321465]
# [2417.351055 2417.412405 2417.461615 ... 2566.40058  2566.46703
#  2566.511555]
# [2566.53266  2566.59877  2566.64101  ... 2716.81799  2716.84855
#  2716.916295]
# [2716.942095 2717.00889  2717.0654   ... 2866.06153  2866.128055
#  2866.161385]
# [2866.21107 2866.26434 2866.321   ... 3013.34208 3013.39927 3013.4606 ]
# [3013.487295 3013.558355 3013.60211  ... 3165.517825 3165.56521
#  3165.62005 ]
# [3165.650365 3165.722475 3165.75158  ... 3317.83897  3317.875705
#  3317.948085]
# [3317.9675   3318.025265 3318.081815 ... 3474.470115 3474.52227
#  3474.567745]
# [3474.60404  3474.66586  3474.7292   ... 3630.05765  3630.088905
#  3630.152775]
# [3630.18519  3630.23852  3630.298365 ... 3787.648445 3787.694365
#  3787.735295]
# [3787.77449 3787.84921 3787.90416 ... 3950.67257 3950.57368 3950.49376]
# [3950.466415 3950.56982  3950.72821  ... 4108.2049   4108.26063
#  4108.317865]
# [4108.340355 4108.405275 4108.45016  ... 4264.079345 4264.111545
#  4264.14655 ]
# [4264.18544  4264.237485 4264.30779  ... 4425.771785 4425.78768
#  4425.86062 ]
# [4425.88443  4425.954225 4426.016245 ... 4589.034455 4589.085065
#  4589.13831 ]
# [4589.17017  4589.230915 4589.27779  ... 4756.878935 4756.935405
#  4756.956285]
# [4757.00093  4757.08885  4757.11245  ... 4930.807355 4930.844835
#  4930.899305]
# [4930.924295 4930.99575  4931.03288  ... 5107.90069  5107.933705
#  5108.006245]
# [5108.02724  5108.096415 5108.14092  ... 5294.8021   5294.846345
#  5294.909225]
# [5294.9374   5295.001565 5295.05611  ... 5483.19536  5483.214305
#  5483.26141 ]
# [5483.300075 5483.368165 5483.41433  ... 5683.55498  5683.600555
#  5683.663935]
# [5683.691255 5683.773075 5683.820405 ... 5893.298605 5893.330295
#  5893.358435]
# [5893.3728   5893.447015 5893.519255 ... 6114.86316  6114.92526
#  6114.976465]
# [6114.997275 6115.072365 6115.121015 ... 6346.64439  6346.69652
#  6346.737515]
# [6346.7853   6346.86718  6346.907705 ... 6579.872195 6579.94469
#  6579.992485]
# [6579.999685 6580.054055 6580.113705 ... 6821.151575 6821.188485
#  6821.253735]
# [6821.280505 6821.35044  6821.396135 ... 7063.0166   7063.08217
#  7063.104965]
# [7063.114425 7063.180895 7063.248605 ... 7320.09616  7320.140555
#  7320.1723  ]
# [7320.209365 7320.27655  7320.36934  ... 7582.21882  7582.28029
#  7582.34016 ]
# [7582.366955 7582.419095 7582.47417  ... 7846.21549  7846.265505
#  7846.310435]
# [7846.35319  7846.41603  7846.47295  ... 8114.381705 8114.42297
#  8114.481975]
